# %%
import pandas as pd

# %%
#Had to load these locally because uploading them to drive was too slow
s2 = pd.read_pickle("pickles/S2.pkl")
s3 = pd.read_pickle("pickles/S3.pkl")
s4 = pd.read_pickle("pickles/S4.pkl")
s5 = pd.read_pickle("pickles/S5.pkl")
s6 = pd.read_pickle("pickles/S6.pkl")
s7 = pd.read_pickle("pickles/S7.pkl")
s8 = pd.read_pickle("pickles/S8.pkl")
s9 = pd.read_pickle("pickles/S9.pkl")
s10 = pd.read_pickle("pickles/S10.pkl")
s11 = pd.read_pickle("pickles/S11.pkl")
s13 = pd.read_pickle("pickles/S13.pkl")
s14 = pd.read_pickle("pickles/S14.pkl")
s15 = pd.read_pickle("pickles/S15.pkl")
s16 = pd.read_pickle("pickles/S16.pkl")
s17 = pd.read_pickle("pickles/S17.pkl")

# %%
# 1: collecting all ECG data
ecg2 = pd.DataFrame(s2['signal']['chest']['ECG'])
list2 = ecg2[0].to_list()

ecg3 = pd.DataFrame(s3['signal']['chest']['ECG'])
list3 = ecg3[0].to_list()

ecg4 = pd.DataFrame(s4['signal']['chest']['ECG'])
list4 = ecg4[0].to_list()

ecg5 = pd.DataFrame(s5['signal']['chest']['ECG'])
list5 = ecg5[0].to_list()

ecg6 = pd.DataFrame(s6['signal']['chest']['ECG'])
list6 = ecg6[0].to_list()

ecg7 = pd.DataFrame(s7['signal']['chest']['ECG'])
list7 = ecg7[0].to_list()

ecg8 = pd.DataFrame(s8['signal']['chest']['ECG'])
list8 = ecg8[0].to_list()

ecg9 = pd.DataFrame(s9['signal']['chest']['ECG'])
list9 = ecg9[0].to_list()

ecg10 = pd.DataFrame(s10['signal']['chest']['ECG'])
list10 = ecg10[0].to_list()

ecg11 = pd.DataFrame(s11['signal']['chest']['ECG'])
list11 = ecg11[0].to_list()

ecg13 = pd.DataFrame(s13['signal']['chest']['ECG'])
list13 = ecg13[0].to_list()

ecg14 = pd.DataFrame(s14['signal']['chest']['ECG'])
list14 = ecg14[0].to_list()

ecg15 = pd.DataFrame(s15['signal']['chest']['ECG'])
list15 = ecg15[0].to_list()

ecg16 = pd.DataFrame(s16['signal']['chest']['ECG'])
list16 = ecg16[0].to_list()

ecg17 = pd.DataFrame(s17['signal']['chest']['ECG'])
list17 = ecg17[0].to_list()

# %%
# 1: collecting all ECG data
ECG = list2+list3+list4+list5+list6+list7+list8+list9+list10+list11+list13+list14+list15+list16+list17
len(ECG)
# Out:
# 60807600

# %%
# 2: collecting all EMG data
emg2 = pd.DataFrame(s2['signal']['chest']['EMG'])
list2a = emg2[0].to_list()

emg3 = pd.DataFrame(s3['signal']['chest']['EMG'])
list3a = emg3[0].to_list()

emg4 = pd.DataFrame(s4['signal']['chest']['EMG'])
list4a = emg4[0].to_list()

emg5 = pd.DataFrame(s5['signal']['chest']['EMG'])
list5a = emg5[0].to_list()

emg6 = pd.DataFrame(s6['signal']['chest']['EMG'])
list6a = emg6[0].to_list()

emg7 = pd.DataFrame(s7['signal']['chest']['EMG'])
list7a = emg7[0].to_list()

emg8 = pd.DataFrame(s8['signal']['chest']['EMG'])
list8a = emg8[0].to_list()

emg9 = pd.DataFrame(s9['signal']['chest']['EMG'])
list9a = emg9[0].to_list()

emg10 = pd.DataFrame(s10['signal']['chest']['EMG'])
list10a = emg10[0].to_list()

emg11 = pd.DataFrame(s11['signal']['chest']['EMG'])
list11a = emg11[0].to_list()

emg13 = pd.DataFrame(s13['signal']['chest']['EMG'])
list13a = emg13[0].to_list()

emg14 = pd.DataFrame(s14['signal']['chest']['EMG'])
list14a = emg14[0].to_list()

emg15 = pd.DataFrame(s15['signal']['chest']['EMG'])
list15a = emg15[0].to_list()

emg16 = pd.DataFrame(s16['signal']['chest']['EMG'])
list16a = emg16[0].to_list()

emg17 = pd.DataFrame(s17['signal']['chest']['EMG'])
list17a = emg17[0].to_list()

# %%
# 2: collecting all EMG data
EMG = list2a+list3a+list4a+list5a+list6a+list7a+list8a+list9a+list10a+list11a+list13a+list14a+list15a+list16a+list17a
len(EMG)
# Out:
# 60807600

# %%
# 3: collecting all EDA data
eda2 = pd.DataFrame(s2['signal']['chest']['EDA'])
list2b = eda2[0].to_list()

eda3 = pd.DataFrame(s3['signal']['chest']['EDA'])
list3b = eda3[0].to_list()

eda4 = pd.DataFrame(s4['signal']['chest']['EDA'])
list4b = eda4[0].to_list()

eda5 = pd.DataFrame(s5['signal']['chest']['EDA'])
list5b = eda5[0].to_list()

eda6 = pd.DataFrame(s6['signal']['chest']['EDA'])
list6b = eda6[0].to_list()

eda7 = pd.DataFrame(s7['signal']['chest']['EDA'])
list7b = eda7[0].to_list()

eda8 = pd.DataFrame(s8['signal']['chest']['EDA'])
list8b = eda8[0].to_list()

eda9 = pd.DataFrame(s9['signal']['chest']['EDA'])
list9b = eda9[0].to_list()

eda10 = pd.DataFrame(s10['signal']['chest']['EDA'])
list10b = eda10[0].to_list()

eda11 = pd.DataFrame(s11['signal']['chest']['EDA'])
list11b = eda11[0].to_list()

eda13 = pd.DataFrame(s13['signal']['chest']['EDA'])
list13b = eda13[0].to_list()

eda14 = pd.DataFrame(s14['signal']['chest']['EDA'])
list14b = eda14[0].to_list()

eda15 = pd.DataFrame(s15['signal']['chest']['EDA'])
list15b = eda15[0].to_list()

eda16 = pd.DataFrame(s16['signal']['chest']['EDA'])
list16b = eda16[0].to_list()

eda17 = pd.DataFrame(s17['signal']['chest']['EDA'])
list17b = eda17[0].to_list()

EDA = list2b+list3b+list4b+list5b+list6b+list7b+list8b+list9b+list10b+list11b+list13b+list14b+list15b+list16b+list17b
len(EDA)

# %%
# 4: collecting all Temp data
temp2 = pd.DataFrame(s2['signal']['chest']['Temp'])
list2c = temp2[0].to_list()

temp3 = pd.DataFrame(s3['signal']['chest']['Temp'])
list3c = temp3[0].to_list()

temp4 = pd.DataFrame(s4['signal']['chest']['Temp'])
list4c = temp4[0].to_list()

temp5 = pd.DataFrame(s5['signal']['chest']['Temp'])
list5c = temp5[0].to_list()

temp6 = pd.DataFrame(s6['signal']['chest']['Temp'])
list6c = temp6[0].to_list()

temp7 = pd.DataFrame(s7['signal']['chest']['Temp'])
list7c = temp7[0].to_list()

temp8 = pd.DataFrame(s8['signal']['chest']['Temp'])
list8c = temp8[0].to_list()

temp9 = pd.DataFrame(s9['signal']['chest']['Temp'])
list9c = temp9[0].to_list()

temp10 = pd.DataFrame(s10['signal']['chest']['Temp'])
list10c = temp10[0].to_list()

temp11 = pd.DataFrame(s11['signal']['chest']['Temp'])
list11c = temp11[0].to_list()

temp13 = pd.DataFrame(s13['signal']['chest']['Temp'])
list13c = temp13[0].to_list()

temp14 = pd.DataFrame(s14['signal']['chest']['Temp'])
list14c = temp14[0].to_list()

temp15 = pd.DataFrame(s15['signal']['chest']['Temp'])
list15c = temp15[0].to_list()

temp16 = pd.DataFrame(s16['signal']['chest']['Temp'])
list16c = temp16[0].to_list()

temp17 = pd.DataFrame(s17['signal']['chest']['Temp'])
list17c = temp17[0].to_list()

Temp = list2c+list3c+list4c+list5c+list6c+list7c+list8c+list9c+list10c+list11c+list13c+list14c+list15c+list16c+list17c
len(Temp)

# %%
# 5: collecting all Resp data
resp2 = pd.DataFrame(s2['signal']['chest']['Resp'])
list2d = resp2[0].to_list()

resp3 = pd.DataFrame(s3['signal']['chest']['Resp'])
list3d = resp3[0].to_list()

resp4 = pd.DataFrame(s4['signal']['chest']['Resp'])
list4d = resp4[0].to_list()

resp5 = pd.DataFrame(s5['signal']['chest']['Resp'])
list5d = resp5[0].to_list()

resp6 = pd.DataFrame(s6['signal']['chest']['Resp'])
list6d = resp6[0].to_list()

resp7 = pd.DataFrame(s7['signal']['chest']['Resp'])
list7d = resp7[0].to_list()

resp8 = pd.DataFrame(s8['signal']['chest']['Resp'])
list8d = resp8[0].to_list()

resp9 = pd.DataFrame(s9['signal']['chest']['Resp'])
list9d = resp9[0].to_list()

resp10 = pd.DataFrame(s10['signal']['chest']['Resp'])
list10d = resp10[0].to_list()

resp11 = pd.DataFrame(s11['signal']['chest']['Resp'])
list11d = resp11[0].to_list()

resp13 = pd.DataFrame(s13['signal']['chest']['Resp'])
list13d = resp13[0].to_list()

resp14 = pd.DataFrame(s14['signal']['chest']['Resp'])
list14d = resp14[0].to_list()

resp15 = pd.DataFrame(s15['signal']['chest']['Resp'])
list15d = resp15[0].to_list()

resp16 = pd.DataFrame(s16['signal']['chest']['Resp'])
list16d = resp16[0].to_list()

resp17 = pd.DataFrame(s17['signal']['chest']['Resp'])
list17d = resp17[0].to_list()

Resp = list2d+list3d+list4d+list5d+list6d+list7d+list8d+list9d+list10d+list11d+list13d+list14d+list15d+list16d+list17d
len(Resp)
# Out:
# 60807600

# %%
# 6: Collecting label data (condition codes)

code2 = pd.DataFrame(s2['label'])
list2e = resp2[0].to_list()

resp3 = pd.DataFrame(s3['label'])
list3e = resp3[0].to_list()

resp4 = pd.DataFrame(s4['label'])
list4e = resp4[0].to_list()

resp5 = pd.DataFrame(s5['label'])
list5e = resp5[0].to_list()

resp6 = pd.DataFrame(s6['label'])
list6e = resp6[0].to_list()

resp7 = pd.DataFrame(s7['label'])
list7e = resp7[0].to_list()

resp8 = pd.DataFrame(s8['label'])
list8e = resp8[0].to_list()

resp9 = pd.DataFrame(s9['label'])
list9e = resp9[0].to_list()

resp10 = pd.DataFrame(s10['label'])
list10e = resp10[0].to_list()

resp11 = pd.DataFrame(s11['label'])
list11e = resp11[0].to_list()

resp13 = pd.DataFrame(s13['label'])
list13e = resp13[0].to_list()

resp14 = pd.DataFrame(s14['label'])
list14e = resp14[0].to_list()

resp15 = pd.DataFrame(s15['label'])
list15e = resp15[0].to_list()

resp16 = pd.DataFrame(s16['label'])
list16e = resp16[0].to_list()

resp17 = pd.DataFrame(s17['label'])
list17e = resp17[0].to_list()

Resp = list2d+list3d+list4d+list5d+list6d+list7d+list8d+list9d+list10d+list11d+list13d+list14d+list15d+list16d+list17d
len(Resp)
